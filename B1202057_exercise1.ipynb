# %%
#1
print('''長庚大學
醫學系
周芳年''')

#2
a=input('請輸入一個數字')
print(float(a)>10)

#3
a=3
b=5
print(a**b)

#4
a=3
b=5
print(a!=b)

#5a
a=3
b=5
a/=b
print(a)

#5b
a=3/5
print(a)
# Out:
# 長庚大學
# 醫學系
# 周芳年
# 請輸入一個數字7
# False
# 243
# True
# 0.6
# 0.6
